# %%
import pandas as pd

# %%
filepath = "DATA/RAW/table2.csv"
df = pd.read_csv(filepath)

# Print headers
print(len(df.columns),"Headers:")
print(list(df.columns))

# Get unique catalogues
catalogue_column = 'catalogue'  # change if your column has a different name
catalogues = df[catalogue_column].dropna().unique().tolist()

print(len(catalogues),"Catalogues:")
print(catalogues)
# Out:
# 12 Headers:
# ['bsdb', 'ref_idsys', 'id', 'e', 'q', 'period', 'a', 'parallax', 'i', 'catalogue', 'filename', 'line']
# 21 Catalogues:
# ['ORB6', 'J/A+A/546/A69', 'SB9', 'J/A+A/417/263', 'II/150A', 'B/gcvs', 'CEV', 'Hipparcos', 'V/115', 'J/MNRAS/491/5489', 'Svechnikov84', 'V/119 ', 'J/MNRAS/349/1069', 'V/123A', 'J/A+A/311/523', 'V/120', 'J/MNRAS/357/497', 'Svechnikov99', 'V/118', 'LiuHMXB', 'LiuLMXB']
